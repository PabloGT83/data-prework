# %%
well_height = 125
daily_distance = 30
nightly_distance = 20
snail_position = 0

print(well_height)
# Out:
# 125

# %%
days = 0

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-0d6fee091e6f> in <module>
#       1 while snail_position <= well_height:
# ----> 2     snail_position = daily_distance - nightly_distance
#       3     days+=1
#
# KeyboardInterrupt:

# %%
print(days)
# Out:
# 179184098

# %%
print(snail_position)
# Out:
# 10

# %%
while count <= 5:
    print(count)
    count += 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-d78f7d3ad687> in <module>
# ----> 1 while count <= 5:
#       2     print(count)
#       3     count += 1
#
# NameError: name 'count' is not defined

# %%
count = 0
while count <= 5:
    print(count)
    count += 1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
while snail_position <= well_height:
    snail_position = daily_distance - nightly_distance
    print(days)
    days+=1
# Out:
# 179184098
# 179184099
# 179184100
# 179184101
# 179184102
# 179184103
# 179184104
# 179184105
# 179184106
# 179184107
# 179184108
# 179184109
# 179184110
# 179184111
# 179184112
# 179184113
# 179184114
# 179184115
# 179184116
# 179184117
# 179184118
# 179184119
# 179184120
# 179184121
# 179184122
# 179184123
# 179184124
# 179184125
# 179184126
# 179184127
# 179184128
# 179184129
# 179184130
# 179184131
# 179184132
# 179184133
# 179184134
# 179184135
# 179184136
# 179184137
# 179184138
# 179184139
# 179184140
# 179184141
# 179184142
# 179184143
# 179184144
# 179184145
# 179184146
# 179184147
# 179184148
# 179184149
# 179184150
# 179184151
# 179184152
# 179184153
# 179184154
# 179184155
# 179184156
# 179184157
# 179184158
# 179184159
# 179184160
# 179184161
# 179184162
# 179184163
# 179184164
# 179184165
# 179184166
# 179184167
# 179184168
# 179184169
# 179184170
# 179184171
# 179184172
# 179184173
# 179184174
# 179184175
# 179184176
# 179184177
# 179184178
# 179184179
# 179184180
# ...

# %%
snale_scape = False
print(snale_scape)
# Out:
# False

# %%
while snale_scape == False:
    snale_position = daily_distance - nightly_distance
    days += 1
    if (snale_position > well_height):
        snale_scape = True
print(days)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-9e8308bb5258> in <module>
#       1 while snale_scape == False:
#       2     snale_position = daily_distance - nightly_distance
# ----> 3     days += 1
#       4     if (snale_position >> well_height):
#       5         snale_scape = True
#
# KeyboardInterrupt:

# %%
while snale_scape == False:
    snale_position = daily_distance - nightly_distance
    days += 1
    if (snale_position > well_height):
        snale_scape = True
print(days)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-dd0969d0414b> in <module>
#       1 while snale_scape == False:
#       2     snale_position = daily_distance - nightly_distance
# ----> 3     days += 1
#       4     if (snale_position > well_height):
#       5         snale_scape = True
#
# KeyboardInterrupt:

# %%
while snale_scape == False:
    snale_position = daily_distance - nightly_distance
    days+=1
    if (snale_position > well_height):
        snale_scape = True
print(days)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-3dab72245f26> in <module>
#       1 while snale_scape == False:
# ----> 2     snale_position = daily_distance - nightly_distance
#       3     days+=1
#       4     if (snale_position > well_height):
#       5         snale_scape = True
#
# KeyboardInterrupt:

# %%
while snale_scape == False:
    snale_position = daily_distance - nightly_distance
    print(days)
    days += 1
    if (snale_position > well_height):
        snale_scape = True
# Out:
# 267462739
# 267462740
# 267462741
# 267462742
# 267462743
# 267462744
# 267462745
# 267462746
# 267462747
# 267462748
# 267462749
# 267462750
# 267462751
# 267462752
# 267462753
# 267462754
# 267462755
# 267462756
# 267462757
# 267462758
# 267462759
# 267462760
# 267462761
# 267462762
# 267462763
# 267462764
# 267462765
# 267462766
# 267462767
# 267462768
# 267462769
# 267462770
# 267462771
# 267462772
# 267462773
# 267462774
# 267462775
# 267462776
# 267462777
# 267462778
# 267462779
# 267462780
# 267462781
# 267462782
# 267462783
# 267462784
# 267462785
# 267462786
# 267462787
# 267462788
# 267462789
# 267462790
# 267462791
# 267462792
# 267462793
# 267462794
# 267462795
# 267462796
# 267462797
# 267462798
# 267462799
# 267462800
# 267462801
# 267462802
# 267462803
# 267462804
# 267462805
# 267462806
# 267462807
# 267462808
# 267462809
# 267462810
# 267462811
# 267462812
# 267462813
# 267462814
# 267462815
# 267462816
# 267462817
# 267462818
# 267462819
# 267462820
# 267462821
# ...
